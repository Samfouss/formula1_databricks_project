# %%
# Avoir de l'aide
dbutils.secrets.help()

# %%
# Get all scopes name from linking key vault and the secrets in 
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list(scope="sam-1-storage-access-key-scope")

# %%
# dbutils.secrets.get(scope="sam-1-storage-access-key-scope", key="sam-1-storage-access-key")
